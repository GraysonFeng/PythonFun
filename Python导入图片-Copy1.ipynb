# %%
from IPython.display import Image
Image(filename="C:/Users/chen jia ni/Desktop/Titanic图片库/机器学习步骤.png",width=300,height=100)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "http://ww3.sinaimg.cn/mw690/006faQNTgw1f63kcy3kzgj30id05g3yo.jpg")
# Out:
# <img src="http://ww3.sinaimg.cn/mw690/006faQNTgw1f63kcy3kzgj30id05g3yo.jpg"/>
